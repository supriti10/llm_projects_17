# %% [markdown]
# # Tokenizers
#
# Please can I bring you back to the wonderful Google Colab where we'll look at different Tokenizers:

# %% [markdown]
# ## Tokenizer
#
# -> A token is a block of letters together that makes up a part of a word, or it can be a whole word.
#
# -> Maps between Text and Tokens for a particular model.
#
# 1. Translates between text, tokens and token IDs with encode() and decode() methods
#
# 2. Contains a Vocab that can include special tokens to signal information to the LLM, like start of prompt

# %% [markdown]
# ## My Colab Link
#
# https://colab.research.google.com/drive/1RDvSZBGppTC58-YWmfOOzyCg3hvLdUPy?usp=drive_link
