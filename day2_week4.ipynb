# %% [markdown]
# ## Five Leaderboards
#
# ~ A tour of the essential leaderboards for selecting LLMs
#
# 1. Artificial Analysis - THE leaderboard
#
# 2. Vellum - includes API cost and context window
#
# 3. Scale.com - SEAL leaderboards
#
# 4. Hugging Face - Open Source leaderboards
#
# 5. Live Bench - Contamination-free

# %% [markdown]
# ## The Arena
#
# ~ The LM Arena (formerly LMSYS) is an amazing resource
#
# 1. Compare Frontier and Open-source models directly
#
# 2. Blind human evals based on head-to-head comparison
#
# 3. LLMs are measured with an ELO-style score rating

# %% [markdown]
# ## Commercial Use Cases
#
# ~ Automate, then Augment, then Differentiate
#
# 1. ChatGPT Wrapper - Duolingo, Copilots
#
# 2. Specialized - Harvey, nebula.io, Khanmigo, Salesforce Health, Palantir
#
# 3. Agentic - Claude Code, OpenAI Codex, OpenAI Agent
