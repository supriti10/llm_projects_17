# %% [markdown]
# ## WHat's the right LLM for the task at hand?
#
# -> understand the requirements
#
# -> look at the model in 2 ways:
#
# 1. basic information about the model - parameters, context length, pricing
#
# 2. then look at the results - benchmarks, leaderboards, arenas.

# %% [markdown]
# ## Comparing the features of LLMs:
#
# - The Basics (1)
#
# ~ Open-source or closed
#
# ~ Chat / Reasoning / Hybrid
#
# ~ Release date and knowledge cut-off (time till which it has the training data)
#
# ~ Parameters
#
# ~ Training tokens
#
# ~ Context window - total capacity the model has to look back on information from the conversation
#
# - The Basics (2)
#
# ~ Inference cost - API charge or Runtime compute
#
# ~ Training cost
#
# ~ Build cost
#
# ~ Time to Market - how long you are going to take to build the product that you need to build
#
# ~ Rate limits
#
# ~ Speed - how fast the model will respond
#
# ~ Latency - time until it starts bringing back responses that you might be streaming onto your UI
#
# ~ License

# %% [markdown]
# ## The Chinchilla Scaling Law
#
# -> developed by Google
#
# -> idea is to how to scale models
#
# -> number of parameters ~ proportional to the number of training tokens
#
# -> if you are getting diminishing returns from training with more training data, then this law gives you a rule of thumb for scaling your model
#
# -> and vice versa, if you upgrade to a model with double the number of weights, this law suggests you need twice the data
#
# => techniques have been found to compress models:
# 1. pruning the weights through better architecture
#
# 2. inference time - more reasoning, using techniques like rag

# %% [markdown]
# ## Benchmarks
#
# Refer the day1_week4.xlsx sheet

# %% [markdown]
# ## Limitations of Benchmarks
#
# 1. Training Data Contamination - avoid it by changing the metrics all the time
#
# 2. Not consistently applied - hardware on which a model runs is not specified
#
# 3. Too narrow in scope
#
# 4. Hard to measure nuanced reasoning
#
# 5. Saturation
#
# 6. Overfitting - a bit of dataset contamination; meaning a model is overly trained to solve a particular metric
#
# -> And a new concern, not yet proven
#
# - Frontier LLMs may be aware that they are being evaluated
